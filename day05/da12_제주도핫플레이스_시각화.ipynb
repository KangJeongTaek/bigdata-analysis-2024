# %% [markdown]
# ## 빅데이터 실습
#
# ### 제주도 핫플레이스 시각화
#
# #### 데이터 불러오기

# %%
# 필요라이브러리 등록
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster

# %%
import requests
import time
from tqdm import  tqdm

# %%
from matplotlib import rcParams,font_manager,rc
font_path = 'C:/Windows/Fonts/NanumGothicCoding.ttf' #나눔고딕코딩체
font_name = font_manager.FontProperties(fname=font_path).get_name() # 실제 설치된 폰트 이름 조회
rc('font',family=font_name) # 한글깨짐 현상 해결!!
rcParams['axes.unicode_minus'] = False # 한글 사용시 마이너스가 표시가 깨지는 걸 방지

# %%
# 불필요한 경고메시지 제거
import warnings
warnings.filterwarnings('ignore')

# %%
## 데이터 불러오기
rawTotal = pd.read_excel('../day04/data/1_crawling_raw.xlsx')

# %%
rawTotal

# %%
#위치정보 확인
locCounts = rawTotal['place'].value_counts()

# %%
locCounts

# %%
dfLocCounts = pd.DataFrame(locCounts)

# %%
dfLocCounts.to_excel('./data/3_location_counts.xlsx')

# %%
Locations = list(dfLocCounts.index)

# %%
Locations[3]
# Out:
# 'Seogwipo'

# %% [markdown]
# #### 카카오 OPENAPI로 장소 검색
# - 카카오 개발자 사이트에서 애플리케이션 등록
# - 키 발급

# %%
shopName = '알뜨르 비행장'
## keyword는 상호, 건물명 등으로 검색 / address는 주소로 검색
url =f'https://dapi.kakao.com/v2/local/search/keyword.json?query={shopName}'
url

header = {"Authorization" : "본인키"}

places = requests.get(url,headers=header).json()['documents']

places

# %%
# 장소 검색 함수 만들기
def findPlace(searchingKeyward):
    # 1. 검색API 주소 변수
    url =f'https://dapi.kakao.com/v2/local/search/keyword.json?query={searchingKeyward}'

    # 2. 헤더 구성
    header = {"Authorization" : "KakaoAK 개인키 넣기"}

    # API URL 요청
    places = requests.get(url,headers=header).json()['documents']

    # 필요 정보만 추출
    place= places[0]
    name = place['place_name']
    x = place['x']
    y = place['y']
    phoneNum = place['phone']
    addrress = place['address_name']
    return [searchingKeyward,name,phoneNum,addrress,x,y]

# %%
## 테스트
result = findPlace('알뜨르 비행장')
result
# Out:
# ['알뜨르 비행장',
#  '알뜨르비행장',
#  '',
#  '제주특별자치도 서귀포시 대정읍 상모리 1670',
#  '126.271527320164',
#  '33.2047161778831']

# %%
locationResults = []
for loc in tqdm(Locations):
    try:
        data = findPlace(loc)
        locationResults.append(data)
        time.sleep(0.3)
    except IndexError:
        pass
# Out:
# 100%|██████████| 1028/1028 [14:30<00:00,  1.18it/s]

# %%
## list --> DataFram 변경
dfLocationResult = pd.DataFrame(locationResults)

# %%
dfLocationResult.columns = ['초기명','실제명','전화번호','주소','경도','위도']

# %%
dfLocationResult

# %%
dfLocationResult.to_excel('./data/3_3_locations.xlsx',index=False)

# %% [markdown]
# #### 인스타그램 크롤링정보와 카카오API로 주소 검샐결과정보 병함

# %%
location_counts_df = pd.read_excel('./data/3_location_counts.xlsx',index_col=0)
locations_inform_df = pd.read_excel('./data/3_3_locations.xlsx')

# %%
location_data = pd.merge(locations_inform_df,location_counts_df,how='inner',left_on='초기명',right_index=True)

# %%
location_data['실제명'].value_counts()

# %%
## 중복데이터 pivot
location_dataNew = location_data.pivot_table(values='count',index=['실제명','주소','경도','위도'],aggfunc='sum')

# %%
location_dataNew.reset_index(inplace=True)

# %%
location_dataNew

# %%
location_dataNew.to_excel('./data/3_locationsFinal.xlsx',index=False)

# %%
## 위도, 경도가 object에서 float64로 변경
location_dataNew = location_dataNew.astype({'위도':'float64','경도':'float64'})

# %%
location_dataNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   실제명     709 non-null    object
#  1   주소      709 non-null    object
#  2   경도      709 non-null    float64
#  3   위도      709 non-null    float64
#  4   count   709 non-null    int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 27.8+ KB

# %% [markdown]
# #### 지도 시각화
# - folium 사용

# %%
locHanlaMt = [33.362500,126.533694]
map = folium.Map(location=locHanlaMt,zoom_start=11)
for i in range(len(location_dataNew)):
    name = location_dataNew['실제명'][i] # DF 컬럼이름 의 행갑 i
    count = location_dataNew['count'][i]
    size= int(count)
    lat = float(location_dataNew['위도'][i])
    lng = float(location_dataNew['경도'][i])
    folium.CircleMarker(location=(lat,lng),radius=size,color='red',popup=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a36c38efc310cfb03fbc04513c1c7d31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a36c38efc310cfb03fbc04513c1c7d31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a36c38efc310cfb03fbc04513c1c7d31 = L.map(
#                 &quot;map_a36c38efc310cfb03fbc04513c1c7d31&quot;,
#                 {
#                     center: [33.3625, 126.533694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_743e196175ee6a5c9f643a52efc65e62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_743e196175ee6a5c9f643a52efc65e62.addTo(map_a36c38efc310cfb03fbc04513c1c7d31);
#
#
#             var circle_marker_afc84181ce067eb4efe0c2936db93ac8 = L.circleMarker(
#                 [33.46707849152644, 126.33649979086104],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a36c38efc310cfb03fbc04513c1c7d31);
#
#
#         var popup_ddb046aa54ad2ee78784fcfe08bfcf58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b4fb1fdcca30a0bf83f90f220e8aae6 = $(`&lt;div id=&quot;html_7b4fb1fdcca30a0bf83f90f220e8aae6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1158족욕카페&lt;/div&gt;`)[0];
#                 popup_ddb046aa54ad2ee78784fcfe08bfcf58.setContent(html_7b4fb1fdcca30a0bf83f90f220e8aae6);
#
#
#
#         circle_marker_afc84181ce067eb4efe0c2936db93ac8.bindPopup(popup_ddb046aa54ad2ee78784fcfe08bfcf58)
#         ;
#
#
#
#
#             var circle_marker_54c8b001af7d4558cf97af4b38730679 = L.circleMarker(
#                 [33.45699074238026, 126.45510883544576],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a36c38efc310cfb03fbc04513c1c7d31);
#
#
#         var popup_e1ab6afc9166fbfddbb29ff61bb4fe27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c093fddc89314175adf743762137b10b = $(`&lt;div id=&quot;html_c093fddc89314175adf743762137b10b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;73st&lt;/div&gt;`)[0];
#                 popup_e1ab6afc9166fbfddbb29ff61bb4fe27.setContent(html_c093fddc89314175adf743762137b10b);
#
#
#
#         circle_marker_54c8b001af7d4558cf97af4b38730679.bindPopup(popup_e1ab6afc9166fbfddbb29ff61bb4fe27)
#         ;
#
#
#
#
#             var circle_marker_0ea019662032fcd732d4d6ce68b44a06 = L.circleMarker(
#                 [37.26812040180812, 127.000144309653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a36c38efc310cfb03fbc04513c1c7d31);
#
#
#         var popup_6ebbfa08c6998c8ae81d5b7325dd713b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7e695f9ffe8b6e0c2f7b1da98d5daa4 = $(`&lt;div id=&quot;html_e7e695f9ffe8b6e0c2f7b1da98d5daa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CU 수원광장점&lt;/div&gt;`)[0];
#                 popup_6ebbfa08c6998c8ae81d5b7325dd713b.setContent(html_e7e695f9ffe8b6e0c2f7b1da98d5daa4);
#
#
#
#         circle_marker_0ea019662032fcd732d4d6ce68b44a06.bindPopup(popup_6ebbfa08c6998c8ae81d5b7325dd713b)
#         ;
#
#
#
#
#             var circle_marker_8143c0ca81ffd4372cd07a17f78275e9 = L.circleMarker(
#                 [37.52470211311498, 126.91674992301569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &qu

# %%
map.save('./data/3_jeju_hotplaces.html')

# %%
## 마커 클러스터

mapLocations = []
mapNames = []
for i in range(len(location_dataNew)):
    data = location_dataNew.iloc[i]
    mapLocations.append((float(data['위도']),float(data['경도'])))
    mapNames.append(data['실제명'])

locHanlaMt = [33.362500,126.533694]
map = folium.Map(location=locHanlaMt,zoom_start=11)

markerCluster = MarkerCluster(
    locations =mapLocations,popups=mapNames,
    name = '제주 핫플레이스',
    overlay=True,
    control=True
)

markerCluster.add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83008dd2e83a28a5afd997accd2c619f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83008dd2e83a28a5afd997accd2c619f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83008dd2e83a28a5afd997accd2c619f = L.map(
#                 &quot;map_83008dd2e83a28a5afd997accd2c619f&quot;,
#                 {
#                     center: [33.3625, 126.533694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12a314fa25fd70d0e890eeebda7c26b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_12a314fa25fd70d0e890eeebda7c26b1.addTo(map_83008dd2e83a28a5afd997accd2c619f);
#
#
#             var marker_cluster_23cdd4e6f237a085be9fcd02308fc556 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_d6438fe1a939dd84d3054980cadda246 = L.marker(
#                 [33.46707849152644, 126.33649979086104],
#                 {}
#             ).addTo(marker_cluster_23cdd4e6f237a085be9fcd02308fc556);
#
#
#         var popup_7b7f37fcad0b17b3e434ed479a50a411 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba417b482bd840c0edeb851c937d8c6d = $(`&lt;div id=&quot;html_ba417b482bd840c0edeb851c937d8c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1158족욕카페&lt;/div&gt;`)[0];
#                 popup_7b7f37fcad0b17b3e434ed479a50a411.setContent(html_ba417b482bd840c0edeb851c937d8c6d);
#
#
#
#         marker_d6438fe1a939dd84d3054980cadda246.bindPopup(popup_7b7f37fcad0b17b3e434ed479a50a411)
#         ;
#
#
#
#
#             var marker_f642c42043024961bee5d3f251fd1c79 = L.marker(
#                 [33.45699074238026, 126.45510883544576],
#                 {}
#             ).addTo(marker_cluster_23cdd4e6f237a085be9fcd02308fc556);
#
#
#         var popup_9b500f78606870e45b9fabc81a16f45c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0048f9d7128b8b7c42ad98cf122de953 = $(`&lt;div id=&quot;html_0048f9d7128b8b7c42ad98cf122de953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;73st&lt;/div&gt;`)[0];
#                 popup_9b500f78606870e45b9fabc81a16f45c.setContent(html_0048f9d7128b8b7c42ad98cf122de953);
#
#
#
#         marker_f642c42043024961bee5d3f251fd1c79.bindPopup(popup_9b500f78606870e45b9fabc81a16f45c)
#         ;
#
#
#
#
#             var marker_a8e6093043a03f4e7234b850e9dcd360 = L.marker(
#                 [37.26812040180812, 127.000144309653],
#                 {}
#             ).addTo(marker_cluster_23cdd4e6f237a085be9fcd02308fc556);
#
#
#         var popup_f44ae4e95aba2b909b07472c825fac01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acdb93bd2b16151e4b160cd35e2d7f55 = $(`&lt;div id=&quot;html_acdb93bd2b16151e4b160cd35e2d7f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CU 수원광장점&lt;/div&gt;`)[0];
#                 popup_f44ae4e95aba2b909b07472c825fac01.setContent(html_acdb93bd2b16151e4b160cd35e2d7f55);
#
#
#
#         marker_a8e6093043a03f4e7234b850e9dcd360.bindPopup(popup_f44ae4e95aba2b909b07472c825fac01)
#         ;
#
#
#
#
#             var marker_470e7b237293dc561a19d599fdd50c4e = L.marker(
#                 [37.52470211311498, 126.91674992301569],
#                 {}
#             ).addTo(marker_cluster_23cdd4e6f237a085be9fcd02308fc556);
#
#
#         var popup_c2a20fdc20e63acffe94563fd86599bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2af302c1da2bf2ccd9619ec1fc535392 = $(`&lt;div id=&quot;html_2af302c1da2bf2ccd9619ec1fc535392&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KBS 본관&lt;/div&gt;`)[0];
#                 popup_c2a20fdc20e63acffe94563fd86599bc.setContent(html_2af302c1da2bf2ccd9619ec1fc535392);
#
#
#
#         marker_470e7b237293dc561a19d599fdd50c4e.bindPopup(popup_c2a20fdc20e63acffe94563fd86599bc)
#         ;
#
#
#
#
#             var marker_98ef614ed16c9ea1a55167a3cf875456 = L.marker(
#                 [36.7814052783056, 126.456420317236],
#                 {}
#             ).addTo(marker_cluster_23cdd4e6f237a085be9fcd02308fc556);
#
#
#         var popup_341602ec94da7a4a42d87bd7e7cf9203 = L.popup({&quot;maxWidth&quot;: &quot;100%&q

# %%
map.save('./data/3_jeju_hotplaces_group.html')
